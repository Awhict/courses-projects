# %%
print('123')
# Out:
# 123

# %%
print('456')
# Out:
# 456

# %%
number = 123
type(number)
# Out:
# int

# %%
num = 1.23
type(num)
# Out:
# float

# %%
num = 0.1 + 0.2
print(num)
# Out:
# 0.30000000000000004

# %%
i = 1_000_000_000
i = i + 10_000
print(i)
# Out:
# 1000010000

# %%
test_string1 = 'this is a string'
test_string2 = "这是一个字符串"
print(test_string1)
print(test_string2)
# Out:
# this is a string
# 这是一个字符串

# %%
string1 = 'hello'
print(string1[0])    # 正向索引
print(string1[-1])   # 逆向索引
print(string1[0:2])  # 字符串切片(左闭右开)
# Out:
# h
# o
# he

# %%
string2 = '0123456789'
print(string2[0:9:2]) # 开始位置:结束位置:步长
print(string2[0:9:3])
# Out:
# 02468
# 036

# %%
print(int(True))
print(int(False))
# Out:
# 1
# 0

# %%
a, b, c = 1, 2, 3
print(a)
print(c)
# Out:
# 1
# 3

# %%
x, y = 1, 2
print('before:')
print('x =',x)
print('y =',y)
x, y = y, x
print('after:')
print('x =',x)
print('y =',y)
# Out:
# before:
# x = 1
# y = 2
# after:
# x = 2
# y = 1

# %%
print('1\n2')
# Out:
# 1
# 2

# %%
x = 1
eval('x + 1')  # eval()函数：将字符串解析并执行
# Out:
# 2

# %%
name = 'Tom'
weight = 60.12345
print("My name is {} and I am {:.2f} kg.".format(name,weight)) # {}作为占位符
print("My name is %s and I am %.2f kg."%(name,weight))         # %作为占位符
# Out:
# My name is Tom and I am 60.12 kg.
# My name is Tom and I am 60.12 kg.
